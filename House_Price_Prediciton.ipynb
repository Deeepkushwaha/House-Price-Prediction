# %%
import pandas as pd

# %%
df=pd.read_csv("dataset/ncr_house_price.csv")
df
# Out:
#       bedrooms  house_size  floor       city   price
# 0          5.0      2153.0    3.0  Bengaluru  696376
# 1          5.0      3320.0    2.0  Bengaluru  928494
# 2          3.0      1253.0    3.0   Gurugram  392006
# 3          4.0       717.0    2.0   Gurugram  356077
# 4          2.0      1404.0    2.0        NaN  266257
# ...        ...         ...    ...        ...     ...
# 1995       1.0       651.0    2.0   Gurugram  184961
# 1996       2.0      3138.0    NaN   Gurugram  595168
# 1997       4.0      2656.0    1.0  Bengaluru  749210
# 1998       1.0      1054.0    1.0      Noida  138198
# 1999       5.0      2412.0    2.0      Noida  497441
#
# [2000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# bedrooms      100
# house_size    100
# floor         100
# city          100
# price           0
# dtype: int64

# %%
df[df.bedrooms.isnull()]
# Out:
#       bedrooms  house_size  floor       city   price
# 21         NaN      3913.0    1.0   Gurugram  693837
# 30         NaN      3831.0    2.0      Noida  598209
# 46         NaN       644.0    NaN  Bengaluru  391933
# 73         NaN      2676.0    1.0  Bengaluru  818045
# 88         NaN      3365.0    1.0      Noida  439174
# ...        ...         ...    ...        ...     ...
# 1931       NaN      2085.0    2.0  Bengaluru  466802
# 1958       NaN       986.0    3.0      Noida  276975
# 1970       NaN      1322.0    3.0      Noida  343052
# 1979       NaN      3435.0    1.0   Gurugram  602237
# 1989       NaN      2454.0    3.0  Bengaluru  674559
#
# [100 rows x 5 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df.dropna(subset=['bedrooms'])
df
# Out:
#       bedrooms  house_size  floor       city   price
# 0          5.0      2153.0    3.0  Bengaluru  696376
# 1          5.0      3320.0    2.0  Bengaluru  928494
# 2          3.0      1253.0    3.0   Gurugram  392006
# 3          4.0       717.0    2.0   Gurugram  356077
# 4          2.0      1404.0    2.0        NaN  266257
# ...        ...         ...    ...        ...     ...
# 1995       1.0       651.0    2.0   Gurugram  184961
# 1996       2.0      3138.0    NaN   Gurugram  595168
# 1997       4.0      2656.0    1.0  Bengaluru  749210
# 1998       1.0      1054.0    1.0      Noida  138198
# 1999       5.0      2412.0    2.0      Noida  497441
#
# [1900 rows x 5 columns]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1621, 5)

# %%
df
# Out:
#       bedrooms  house_size  floor       city   price
# 0          5.0      2153.0    3.0  Bengaluru  696376
# 1          5.0      3320.0    2.0  Bengaluru  928494
# 2          3.0      1253.0    3.0   Gurugram  392006
# 3          4.0       717.0    2.0   Gurugram  356077
# 5          4.0      1061.0    1.0   Gurugram  354143
# ...        ...         ...    ...        ...     ...
# 1994       4.0      3137.0    1.0      Noida  526054
# 1995       1.0       651.0    2.0   Gurugram  184961
# 1997       4.0      2656.0    1.0  Bengaluru  749210
# 1998       1.0      1054.0    1.0      Noida  138198
# 1999       5.0      2412.0    2.0      Noida  497441
#
# [1621 rows x 5 columns]

# %%
df.bedrooms.value_counts()
# Out:
# bedrooms
# 4.0    353
# 2.0    329
# 5.0    319
# 3.0    316
# 1.0    304
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1621 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bedrooms    1621 non-null   float64
#  1   house_size  1621 non-null   float64
#  2   floor       1621 non-null   float64
#  3   city        1621 non-null   object
#  4   price       1621 non-null   int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 76.0+ KB

# %%
df.city.value_counts()
# Out:
# city
# Gurugram     574
# Bengaluru    564
# Noida        483
# Name: count, dtype: int64

# %%
df.city=df.city.map({'Bengaluru':0,'Gurugram':1,'Noida':2})
df
# Out:
#       bedrooms  house_size  floor  city   price
# 0          5.0      2153.0    3.0     0  696376
# 1          5.0      3320.0    2.0     0  928494
# 2          3.0      1253.0    3.0     1  392006
# 3          4.0       717.0    2.0     1  356077
# 5          4.0      1061.0    1.0     1  354143
# ...        ...         ...    ...   ...     ...
# 1994       4.0      3137.0    1.0     2  526054
# 1995       1.0       651.0    2.0     1  184961
# 1997       4.0      2656.0    1.0     0  749210
# 1998       1.0      1054.0    1.0     2  138198
# 1999       5.0      2412.0    2.0     2  497441
#
# [1621 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.bedrooms,df.price)
plt.show()

# %%
plt.scatter(df.house_size,df.price)
plt.show()

# %%
plt.scatter(df.floor,df.price)
plt.show()

# %%
plt.scatter(df.city,df.price)
plt.show()

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
X
# Out:
# array([[5.000e+00, 2.153e+03, 3.000e+00, 0.000e+00],
#        [5.000e+00, 3.320e+03, 2.000e+00, 0.000e+00],
#        [3.000e+00, 1.253e+03, 3.000e+00, 1.000e+00],
#        ...,
#        [4.000e+00, 2.656e+03, 1.000e+00, 0.000e+00],
#        [1.000e+00, 1.054e+03, 1.000e+00, 2.000e+00],
#        [5.000e+00, 2.412e+03, 2.000e+00, 2.000e+00]])

# %%
y
# Out:
# array([696376, 928494, 392006, ..., 749210, 138198, 497441], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.9464309903622674

# %%
lr.score(X_test,y_test)
# Out:
# 0.9536724799320364

# %%
from sklearn.metrics import r2_score,accuracy_score

# %%
y_pred=lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9536724799320364

# %%
sample=[3,1000,3,1]

# %%
lr.predict([sample])
# Out:
# array([327747.18123411])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(random_state=42)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf.score(X_train,y_train)
# Out:
# 0.9979610688355527

# %%
y_pred=rf.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9873455286172387

# %%
sample=[3,1000,3,1]

# %%
rf.predict([sample])
# Out:
# array([353939.])

# %%
bedrooms=float(input('enter no. of bedrooms='))
size=float(input('enter size(sqrt)='))
floor=float(input('enter floor='))
city=input("enter city['Bengaluru','Gurugram','Noida']=")

if city=='Bengaluru':city=0
elif city=='Gurugram':city=1
elif city=='Noida':city=2

new_sample=[bedrooms,size,floor,city]
print(rf.predict([new_sample]))
# Out:
# enter no. of bedrooms= 3
# enter size(sqrt)= 1000
# enter floor= 3
# enter city['Bengaluru','Gurugram','Noida']= 1
# [353939.]
